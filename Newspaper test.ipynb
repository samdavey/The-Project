# %%
# pip install newspaper3k
import newspaper

# %%
url = 'http://www.forbes.com/sites/trevornace/2016/02/17/largest-diamond-found-angola-flawless-404-carats/#441e7eac681d'
a = newspaper.Article(url)

def print_article(article):
    print('a', a)
    print('a.config', a.config)
    print('a.extractor', a.extractor)
    print('a.source_url', a.source_url)
    print('a.url', a.url)
    print('a.title', a.title)
    print('a.top_img', a.top_img)
    print('a.meta_img', a.meta_img)
    print('a.imgs', a.imgs)
    print('a.movies', a.movies)
    print('a.text', a.text)
    print('a.keywords', a.keywords)
    print('a.tags', a.tags)
    print('a.authors', a.authors)
    print('a.publish_date', a.publish_date)
    print('a.summary', a.summary)
    print('a.html', a.html)
    print('a.article_html', a.article_html)
    print('a.is_parsed', a.is_parsed)
    print('a.is_downloaded', a.is_downloaded)
    print('a.meta_description', a.meta_description)
    print('a.meta_lang', a.meta_lang)
    print('a.meta_favicon', a.meta_favicon)
    print('a.meta_data', a.meta_data)
    print('a.canonical_link', a.canonical_link)
    print('a.top_node', a.top_node)
    print('a.clean_top_node', a. clean_top_node)
    print('a.doc', a.doc)
    print('a.clean_doc', a.clean_doc)
    print('a.additional_data', a.additional_data)
    pass

# %%
print_article(a)
# Out:
# a <newspaper.article.Article object at 0x0000024DEB6B5080>
# a.config <newspaper.configuration.Configuration object at 0x0000024DEB6B5128>
# a.extractor <newspaper.extractors.ContentExtractor object at 0x0000024DEB6B5160>
# a.source_url http://www.forbes.com
# a.url http://www.forbes.com/sites/trevornace/2016/02/17/largest-diamond-found-angola-flawless-404-carats/#441e7eac681d
# a.title
# a.top_img
# a.meta_img
# a.imgs []
# a.movies []
# a.text
# a.keywords []
# a.tags set()
# a.authors []
# a.publish_date
# a.summary
# a.html
# a.article_html
# a.is_parsed False
# a.is_downloaded False
# a.meta_description
# a.meta_lang
# a.meta_favicon
# a.meta_data {}
# a.canonical_link
# a.top_node None
# a.clean_top_node None
# a.doc None
# a.clean_doc None
# a.additional_data {}

# %%
a.download()
print_article(a)
# Out:
# a <newspaper.article.Article object at 0x0000024DEB6B5080>
# a.config <newspaper.configuration.Configuration object at 0x0000024DEB6B5128>
# a.extractor <newspaper.extractors.ContentExtractor object at 0x0000024DEB6B5160>
# a.source_url http://www.forbes.com
# a.url http://www.forbes.com/sites/trevornace/2016/02/17/largest-diamond-found-angola-flawless-404-carats/#441e7eac681d
# a.title
# a.top_img
# a.meta_img
# a.imgs []
# a.movies []
# a.text
# a.keywords []
# a.tags set()
# a.authors []
# a.publish_date
# a.summary
# ...

# %%
a.parse()
print_article(a)
# Out:
# a <newspaper.article.Article object at 0x0000024DEB6B5080>
# a.config <newspaper.configuration.Configuration object at 0x0000024DEB6B5128>
# a.extractor <newspaper.extractors.ContentExtractor object at 0x0000024DEB6B5160>
# a.source_url http://www.forbes.com
# a.url http://www.forbes.com/sites/trevornace/2016/02/17/largest-diamond-found-angola-flawless-404-carats/#441e7eac681d
# a.title The Largest Diamond Ever Found In Angola Is 404 Carats And Nearly Flawless
# a.top_img http://blogs-images.forbes.com/trevornace/files/2016/02/largest-diamond-angola-1-1200x469.jpg
# a.meta_img http://blogs-images.forbes.com/trevornace/files/2016/02/largest-diamond-angola-1-1200x469.jpg
# a.imgs {'http://blogs-images.forbes.com/trevornace/files/2016/02/largest-diamond-angola-1-1200x469.jpg'}
# a.movies []
# a.text
# a.keywords []
# a.tags set()
# a.authors []
# a.publish_date 2016-02-17 00:00:00
# a.summary
# ...

# %%
a.nlp()
print_article(a)
# Out:
# a <newspaper.article.Article object at 0x0000024DEB6B5080>
# a.config <newspaper.configuration.Configuration object at 0x0000024DEB6B5128>
# a.extractor <newspaper.extractors.ContentExtractor object at 0x0000024DEB6B5160>
# a.source_url http://www.forbes.com
# a.url http://www.forbes.com/sites/trevornace/2016/02/17/largest-diamond-found-angola-flawless-404-carats/#441e7eac681d
# a.title The Largest Diamond Ever Found In Angola Is 404 Carats And Nearly Flawless
# a.top_img http://blogs-images.forbes.com/trevornace/files/2016/02/largest-diamond-angola-1-1200x469.jpg
# a.meta_img http://blogs-images.forbes.com/trevornace/files/2016/02/largest-diamond-angola-1-1200x469.jpg
# a.imgs {'http://blogs-images.forbes.com/trevornace/files/2016/02/largest-diamond-angola-1-1200x469.jpg'}
# a.movies []
# a.text
# a.keywords ['404', 'angola', 'flawless', 'carats', 'diamond', 'largest', 'nearly']
# a.tags set()
# a.authors []
# a.publish_date 2016-02-17 00:00:00
# a.summary
# ...
